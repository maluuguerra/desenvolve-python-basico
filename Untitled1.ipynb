# %%
print("Q1.")
print("a c e")

# %%
print("Q2")
print("a- 7")
print("b- A soma não poderá ser efetuada, ja que os números a serem somados não fooram declarados.")
print("c- 11")
print("d- O primeriro erro se encontra na linha 1, onde o nome da variável é declarada de forma incorreta. o segundo erro se encontra na linha 2, a variável juros deve ser declara da esquerda e seu valor atribuido na direita.")
# Out:
# Q2
# a- 7
# b- A soma não poderá ser efetuada, ja que os números a serem somados não fooram declarados.
# c- 11
# d- O primeriro erro se encontra na linha 1, onde o nome da variável é declarada de forma incorreta. o segundo erro se encontra na linha 2, a variável juros deve ser declara da esquerda e seu valor atribuido na direita.

# %%
print("Q3.")
num1 = 2
num2 = 3
num3 = 8
media = ((num1 + num2 + num3)/3)
print(media)
# Out:
# Q3.
# 4.333333333333333

# %%
print("Q4.")

velocidade = 90
equivalente = 90 / 3.6

print(equivalente)
# Out:
# Q4.
# 25.0

# %%
nome = "Maria Luiza"

print("Meu nome é" )
print(nome)
# Out:
# Meu nome é
# Maria Luiza
